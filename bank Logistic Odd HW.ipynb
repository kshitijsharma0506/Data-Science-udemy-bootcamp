# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv("C:\\Users\\kshit\\Data science\\Part_5_Advanced_Statistical_Methods_(Machine_Learning)\\S36_L245\\Bank-data.csv")
raw_data
# Out:
#      Unnamed: 0  interest_rate  credit  march  may  previous  duration    y
# 0             0          1.334     0.0    1.0  0.0       0.0     117.0   no
# 1             1          0.767     0.0    0.0  2.0       1.0     274.0  yes
# 2             2          4.858     0.0    1.0  0.0       0.0     167.0   no
# 3             3          4.120     0.0    0.0  0.0       0.0     686.0  yes
# 4             4          4.856     0.0    1.0  0.0       0.0     157.0   no
# ..          ...            ...     ...    ...  ...       ...       ...  ...
# 513         513          1.334     0.0    1.0  0.0       0.0     204.0   no
# 514         514          0.861     0.0    0.0  2.0       1.0     806.0  yes
# 515         515          0.879     0.0    0.0  0.0       0.0     290.0   no
# 516         516          0.877     0.0    0.0  5.0       1.0     473.0  yes
# 517         517          4.965     0.0    0.0  0.0       0.0     142.0   no
#
# [518 rows x 8 columns]

# %%
data=raw_data.copy()
data=data.drop({"Unnamed: 0"},axis=1)
data["y"]=data["y"].map({"yes":1,"no":0})
data
# Out:
#      interest_rate  credit  march  may  previous  duration  y
# 0            1.334     0.0    1.0  0.0       0.0     117.0  0
# 1            0.767     0.0    0.0  2.0       1.0     274.0  1
# 2            4.858     0.0    1.0  0.0       0.0     167.0  0
# 3            4.120     0.0    0.0  0.0       0.0     686.0  1
# 4            4.856     0.0    1.0  0.0       0.0     157.0  0
# ..             ...     ...    ...  ...       ...       ... ..
# 513          1.334     0.0    1.0  0.0       0.0     204.0  0
# 514          0.861     0.0    0.0  2.0       1.0     806.0  1
# 515          0.879     0.0    0.0  0.0       0.0     290.0  0
# 516          0.877     0.0    0.0  5.0       1.0     473.0  1
# 517          4.965     0.0    0.0  0.0       0.0     142.0  0
#
# [518 rows x 7 columns]

# %%
y=data["y"]
x1=data[{"interest_rate","duration"}]

# %%
x=sm.add_constant(x1)
reg_log=sm.Logit(y,x)
result_log=reg_log.fit()
result_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.395898
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  518
# Model:                          Logit   Df Residuals:                      515
# Method:                           MLE   Df Model:                            2
# Date:                Fri, 08 May 2020   Pseudo R-squ.:                  0.4288
# Time:                        16:25:38   Log-Likelihood:                -205.08
# converged:                       True   LL-Null:                       -359.05
# Covariance Type:            nonrobust   LLR p-value:                 1.348e-67
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0473      0.241     -0.196      0.844      -0.520       0.425
# duration          0.0064      0.001      9.384      0.000       0.005       0.008
# interest_rate    -0.8072      0.079    -10.242      0.000      -0.962      -0.653
# =================================================================================
# """
